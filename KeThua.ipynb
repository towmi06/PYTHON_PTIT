# %% [markdown]
# ## KE THUA:
# 1. tao lop cha
# 2. khi tao lop con, khai bao them lop cha (vd: class Student(person):)
# ![image.png](attachment:b9267b1f-98fb-481e-8dd8-f52eed0ae88f.png)
# 3. subclassing:
#
#     DE goi ham init cua lop cha thi can them lop cha o dau vd: ten cua lop cha or supper
#
#    ![image.png](attachment:de5c4eae-f805-4d7e-b275-5bd8d5b23fd9.png)
#
# ## Ghi de
# ![image.png](attachment:b1caa123-e78c-4823-a9f3-0649344da899.png)
#
# ## Ke thua: tu nhieu ham khac nhau
